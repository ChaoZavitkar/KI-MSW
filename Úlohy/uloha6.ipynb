# %%
#Dependencies
from turtle import position
import pyautogui
import time
import numpy as np
import random as r
positions = []
seed = 0

# %%
print('Move your mouse randomly around the screen for next 5 seconds to create random seed.')
for i in range(25):
    x, y = pyautogui.position()
    positions.append((x, y))
    print(f'Mouse position '+str(x) + ' '+str(y) + ' saved.')
    for i in positions:
        seed += np.math.factorial(sum(i))
    time.sleep(0.2)
print(f'Your randomly generated seed is: {seed}')
# Out:
# Move your mouse randomly around the screen for next 5 seconds to create random seed.
# Mouse position 518 114 saved.
# C:\Users\GTX\AppData\Local\Temp\ipykernel_24796\2688670530.py:7: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   seed += np.math.factorial(sum(i))
# Mouse position 798 162 saved.
# Mouse position 1047 191 saved.
# Mouse position 1047 191 saved.
# Mouse position 1047 191 saved.
# Mouse position 1047 191 saved.
# Mouse position 1047 191 saved.
# Mouse position 1047 191 saved.
# Mouse position 1047 191 saved.
# Mouse position 1049 197 saved.
# Mouse position 1049 197 saved.
# Mouse position 1051 200 saved.
# Mouse position 1051 200 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Mouse position 1051 202 saved.
# Your randomly generated seed is: ...
